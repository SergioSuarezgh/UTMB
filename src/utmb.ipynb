# %%
import pandas as pd
import numpy as np
import re
import io
import warnings

import generador

pd.set_option('display.max_columns',None)
pd.set_option('display.max_rows',None)
warnings.filterwarnings('ignore')

# %% [markdown]
# #UTMB17

# %%
utmb17=pd.read_csv('../data/utmb2017.csv')

# %%
utmb17.head()
# Out:
#    index                                   0    1    2         3         4  \
# 0      0                                 NaN  NaN  NaN       NaN       NaN
# 1      1       4 - D'HAENE François\nSalomon  SEH  1.0  19:01:54  00:00:00
# 2      2  2 - JORNET BURGADA Kilian\nSalomon  SEH  2.0  19:16:59  00:15:05
# 3      3            14 - TOLLEFSON Tim\nHoka  SEH  3.0  19:53:00  00:51:06
# 4      4         7 - THEVENARD Xavier\nAsics  SEH  4.0  20:03:39  01:01:45
#
#                 5
# 0             NaN
# 1         Francia
# 2          España
# 3  Estados Unidos
# 4         Francia

# %%
utmb17.drop(0,axis=0,inplace=True)  #Eliminamos primera columna de nulos

columns=['posicion','nombre','cat','pto_cat', 'tiempo','dif','pais']
utmb17.set_axis(columns,axis='columns',inplace=True)  #Modificamos el nombre de las columnas

# %%
utmb17.cat.unique()
# Out:
# array(['SEH', 'V1H', 'V2H', 'V1F', 'SEF', 'ESH', 'V3H', 'V2F'],
#       dtype=object)

# %%
##Modificamos en un solo bucle la columna de cat separando el dato del texto y normalizando el contenido. Además quitamos el float de la columna pto_cat

utmb17['sex']=utmb17.cat
for i in range(1,len(utmb17)+1):
    utmb17.sex[i]=str(utmb17.cat[i])[-1]        #rellenamos la columna sexo con el dato
    utmb17.cat[i]=str(utmb17.cat[i])[:2]        #dejamos solo el dato de categoria en cat
    utmb17.pto_cat[i]=str(utmb17.pto_cat[i])[0] #limpiamos pto_cat
    
    #Normalizamos los datos de sexo
    if utmb17.sex[i]=='n':
        utmb17.sex[i]='N/D'
    elif utmb17.sex[i]=='H':
        utmb17.sex[i]='M'
    elif utmb17.sex[i]=='n':
        utmb17.sex[i]='N/D'
    
    #Normalizamos datos en la columna cat
    if utmb17.cat[i]=='SE' or utmb17.cat[i]=='ES':
       utmb17.cat[i]='SENIOR'
    elif utmb17.cat[i]=='V1':
        utmb17.cat[i]='VET-A'
    elif utmb17.cat[i]=='V2':
        utmb17.cat[i]='VET-B'
    elif utmb17.cat[i]=='V3' : 
        utmb17.cat[i]='VET-C'
        
    
        
utmb17.cat.unique()
# Out:
# array(['SENIOR', 'VET-A', 'VET-B', 'VET-C'], dtype=object)

# %%
utmb17.sex.unique()
# Out:
# array(['M', 'F'], dtype=object)

# %%
##Modificamos la columna de nombre donde esta el dato del dorsal, nombre y club y lo separamos en diferentes listas que luego metemos en las columnas correspondientes

equipos=[]
nombres=[]
for i in utmb17.nombre:
    try:
        div=str(i).upper().split('\n')
        equipos.append(div[1].split('/')[0].upper())
    except:
        equipos.append('NONE')
    
    
    #Normalizamos el nombre con la estructura Nombre APELLIDO
    div_nom=div[0].split('-')
    limpiar_nombre=div_nom[1].split()
    temp=[]
    temp.append(limpiar_nombre)
    temp[0]=limpiar_nombre[-1].lower().capitalize()
    temp[1:]=limpiar_nombre[:-1]
    nombres.append(" ".join(temp))
    
utmb17.nombre=nombres
utmb17['club']=equipos

# %%
marcas=[]
for e in utmb17.club:
    if 'COLUMBIA' in e:
        marcas.append('COLUMBIA')
    elif 'SALOMON' in e:
        marcas.append('SALOMON')
    elif 'NORTH FACE' in e:
        marcas.append('SALOMON')
    elif 'HOKA' in e:
        marcas.append('HOKA')
    elif 'VIBRAM' in e:
        marcas.append('VIBRAM')
    elif 'ADIDAS' in e:
        marcas.append('ADIDAS')
    elif 'PATAGONIA' in e:
        marcas.append('PATAGONIA')
    elif 'NIKE' in e:
        marcas.append('NIKE')
    elif 'RAIDLIGHT' in e:
        marcas.append('RAIDLIGHT')
    elif 'SPORTIVA' in e:
        marcas.append('SPORTIVA')
    elif 'COMPRESSPORT' in e:
        marcas.append('COMPRESSPORT')
    elif 'ALTRA' in e:
        marcas.append('ALTRA')
    elif 'DYNAFIT' in e:
        marcas.append('DYNAFIT')
    elif 'NEW BALANCE' in e:
        marcas.append('NEW BALANCE')
    else:
        marcas.append('N/D')
        
marcas
# Out:
# ['SALOMON',
#  'SALOMON',
#  'HOKA',
#  'N/D',
#  'HOKA',
#  'SALOMON',
#  'SALOMON',
#  'VIBRAM',
#  'SALOMON',
#  'COMPRESSPORT',
#  'HOKA',
#  'N/D',
#  'N/D',
#  'NIKE',
#  'NEW BALANCE',
#  'N/D',
#  'HOKA',
#  'N/D',
#  'N/D',
#  'N/D',
#  'SALOMON',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'HOKA',
#  'SPORTIVA',
#  'N/D',
#  'N/D',
#  'SALOMON',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'SALOMON',
#  'N/D',
#  'SPORTIVA',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'RAIDLIGHT',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'SPORTIVA',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'SALOMON',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'COMPRESSPORT',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'VIBRAM',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'SALOMON',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'NIKE',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'SALOMON',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'HOKA',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'COLUMBIA',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'SPORTIVA',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'SALOMON',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'RAIDLIGHT',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'SPORTIVA',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'COLUMBIA',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'RAIDLIGHT',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'COLUMBIA',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  'N/D',
#  ...]

# %%
utmb17=utmb17.reindex(columns=['posicion','tiempo','dif','nombre','club','pais','sex','cat','pto_cat'])  #Recolocamos las columnas

utmb17.reset_index(drop=True,inplace=True)  #Reseteamos el index

# %%
utmb17.info(2)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1687 entries, 0 to 1686
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   posicion  1687 non-null   int64
#  1   tiempo    1687 non-null   object
#  2   dif       1687 non-null   object
#  3   nombre    1687 non-null   object
#  4   club      1687 non-null   object
#  5   pais      1687 non-null   object
#  6   sex       1687 non-null   object
#  7   cat       1687 non-null   object
#  8   pto_cat   1687 non-null   object
# dtypes: int64(1), object(8)
# memory usage: 118.7+ KB

# %%
#Modificamos la columna de idiomas que no está totalmente correcta

utmb17.pais[utmb17.pais=='HK']='Hong Kong'
utmb17.pais[utmb17.pais=='TW']='Taiwan'

# %%
#Normalizamos formato de campos de las columnas añadiendo la configuración final para todas las tablas

utmb17.drop(['pto_cat'],axis='columns',inplace=True) #damos de baja columnas

#Generamos las columnas restanetes

utmb17['carrera']=generador.carrera(len(utmb17),'utmb')
utmb17['anio']=generador.anio(len(utmb17),'2017')

utmb17=utmb17.reindex(columns=['posicion','tiempo','dif','nombre','club','pais','sex','cat','carrera','anio']) #Reorganizamos

# %%
utmb17.to_csv('../data/mod_csv/utmb2017mod.csv', index=False, index_label=False)    
utmb17.to_excel('../data/xlsx/utmb2017mod.xlsx', index=False, index_label=False) #cargamos csv

# %% [markdown]
# #UTMB18

# %%
utmb18=pd.read_csv('../data/utmb2018.csv')

# %%
utmb18.drop(0,axis=0,inplace=True)  #Eliminamos primera columna de nulos

columns=['posicion','nombre','cat','pto_cat', 'tiempo','dif','pais']
utmb18.set_axis(columns,axis='columns',inplace=True)  #Modificamos el nombre de las columnas

# %%
##Modificamos en un solo bucle la columna de cat separando el dato del texto y normalizando el contenido. Además quitamos el float de la columna pto_cat

utmb18['sex']=utmb18.cat
for i in range(1,len(utmb18)+1):
    utmb18.sex[i]=str(utmb18.cat[i])[-1]        #rellenamos la columna sexo con el dato
    utmb18.cat[i]=str(utmb18.cat[i])[:2]        #dejamos solo el dato de categoria en cat
    utmb18.pto_cat[i]=str(utmb18.pto_cat[i])[0] #limpiamos pto_cat
    
    #Normalizamos los datos de sexo
    if utmb18.sex[i]=='n':
        utmb18.sex[i]='N/D'
    elif utmb18.sex[i]=='H':
        utmb18.sex[i]='M'
        
    
    
    
    
    #Normalizamos datos en la columna cat
    if utmb18.cat[i]=='SE' or utmb18.cat[i]=='ES':
       utmb18.cat[i]='SENIOR'
    elif utmb18.cat[i]=='V1':
        utmb18.cat[i]='VET-A'
    elif utmb18.cat[i]=='V2':
        utmb18.cat[i]='VET-B'
    elif utmb18.cat[i]=='V3' or utmb18.cat[i]=='V4': 
        utmb18.cat[i]='VET-C'
    elif utmb18.cat[i]=='na':
        utmb18.cat[i]='N/D'
utmb18.cat.fillna(value='N/D')
        
utmb18.cat.unique()
# Out:
# array(['SENIOR', 'VET-A', 'VET-B', 'N/D', 'VET-C'], dtype=object)

# %%
##Modificamos la columna de nombre donde esta el dato del dorsal, nombre y club y lo separamos en diferentes listas que luego metemos en las columnas correspondientes

equipos=[]
nombres=[]
for i in utmb18.nombre:
    try:
        div=str(i).split('\n')
        equipos.append(div[1].split('/')[0].upper())
    except:
        equipos.append('NONE')
    
    
    #Normalizamos el nombre con la estructura Nombre APELLIDO
    div_nom=div[0].upper().split('-')
    limpiar_nombre=div_nom[1].split()
    temp=[]
    temp.append(limpiar_nombre)
    temp[0]=limpiar_nombre[-1].lower().capitalize()
    temp[1:]=limpiar_nombre[:-1]
    nombres.append(" ".join(temp))
    
utmb18.nombre=nombres
utmb18['club']=equipos

# %%
utmb18=utmb18.reindex(columns=['posicion','tiempo','dif','nombre','club','pais','sex','cat','pto_cat'])  #Recolocamos las columnas

utmb18.reset_index(drop=True,inplace=True)  #Reseteamos el index

# %%
#Modificamos la columna de idiomas que no está totalmente correcta

utmb18.pais[utmb18.pais=='HK']='Hong Kong'
utmb18.pais[utmb18.pais=='TW']='Taiwan'
utmb18.pais[utmb18.pais=='MO']='Moldavia'

# %%
#Normalizamos formato de campos de las columnas añadiendo la configuración final para todas las tablas

utmb18.drop(['pto_cat'],axis='columns',inplace=True) #damos de baja columnas

#Generamos las columnas restanetes

utmb18['carrera']=generador.carrera(len(utmb18),'utmb')
utmb18['anio']=generador.anio(len(utmb18),'2018')


utmb18=utmb18.reindex(columns=['posicion','tiempo','dif','nombre','club','pais','sex','cat','carrera','anio']) #Reorganizamos

# %%
utmb18.to_csv('../data/mod_csv/utmb2018mod.csv', index=False, index_label=False) 
utmb18.to_excel('../data/xlsx/utmb2018mod.xlsx', index=False, index_label=False) #cargamos csv

# %% [markdown]
# #UTMB19

# %%
utmb19=pd.read_csv('../data/utmb2019.csv')

# %%
utmb19.head()
# Out:
#    index                               0    1    2         3         4  \
# 0      0                             NaN  NaN  NaN       NaN       NaN
# 1      1  2 - CAPELL Pau\nTHE NORTH FACE  SEH  1.0  20:19:07  00:00:00
# 2      2            5 - THEVENARD Xavier  SEH  2.0  21:07:56  00:48:49
# 3      3  63 - HAWKER Scott\nTEAM VIBRAM  SEH  3.0  21:48:04  01:28:57
# 4      4         11 - OWENS Tom\nSALOMON  SEH  4.0  22:04:29  01:45:22
#
#                 5
# 0             NaN
# 1          España
# 2         Francia
# 3  Nueva Zelandia
# 4     Reino Unido

# %%
utmb19.drop(0,axis=0,inplace=True)  #Eliminamos primera columna de nulos

columns=['posicion','nombre','cat','pto_cat', 'tiempo','dif','pais']
utmb19.set_axis(columns,axis='columns',inplace=True)  #Modificamos el nombre de las columnas

# %%
##Modificamos en un solo bucle la columna de cat separando el dato del texto y normalizando el contenido. Además quitamos el float de la columna pto_cat

utmb19['sex']=utmb19.cat
for i in range(1,len(utmb19)+1):
    utmb19.sex[i]=str(utmb19.cat[i])[-1]        #rellenamos la columna sexo con el dato
    utmb19.cat[i]=str(utmb19.cat[i])[:2]        #dejamos solo el dato de categoria en cat
    utmb19.pto_cat[i]=str(utmb19.pto_cat[i])[0] #limpiamos pto_cat
    
    
    #Normalizamos los datos de sexo
    if utmb19.sex[i]=='n':
        utmb19.sex[i]='N/D'
    elif utmb19.sex[i]=='H':
        utmb19.sex[i]='M'
    elif utmb19.sex[i]=='n':
        utmb19.sex[i]='N/D'
    
    #Normalizamos datos en la columna cat
    if utmb19.cat[i]=='SE' or utmb19.cat[i]=='ES':
       utmb19.cat[i]='SENIOR'
    elif utmb19.cat[i]=='V1':
        utmb19.cat[i]='VET-A'
    elif utmb19.cat[i]=='V2':
        utmb19.cat[i]='VET-B'
    elif utmb19.cat[i]=='V3' or utmb19.cat[i]=='V4': 
        utmb19.cat[i]='VET-C'
    elif utmb19.cat[i]=='na':
        utmb19.cat[i]='N/D'
utmb19.cat.fillna(value='N/D')
        
utmb19.cat.unique()
# Out:
# array(['SENIOR', 'VET-A', 'VET-B', 'VET-C', 'N/D'], dtype=object)

# %%
##Modificamos la columna de nombre donde esta el dato del dorsal, nombre y club y lo separamos en diferentes listas que luego metemos en las columnas correspondientes

equipos=[]
nombres=[]
for i in utmb19.nombre:
    try:
        div=str(i).split('\n')
        equipos.append(div[1].split('/')[0].upper())
    except:
        equipos.append('NONE')
    
    
    #Normalizamos el nombre con la estructura Nombre APELLIDO
    div_nom=div[0].upper().split('-')
    limpiar_nombre=div_nom[1].split()
    temp=[]
    temp.append(limpiar_nombre)
    temp[0]=limpiar_nombre[-1].lower().capitalize()
    temp[1:]=limpiar_nombre[:-1]
    nombres.append(" ".join(temp))
    
utmb19.nombre=nombres
utmb19['club']=equipos

# %%
utmb19=utmb19.reindex(columns=['posicion','tiempo','dif','nombre','club','pais','sex','cat','pto_cat'])  #Recolocamos las columnas

utmb19.reset_index(drop=True,inplace=True)  #Reseteamos el index

# %%
#Modificamos la columna de idiomas que no está totalmente correcta


utmb19.pais[utmb19.pais=='TW']='Taiwan'
utmb19.pais[utmb19.pais=='HK']='Hong Kong'

# %%
#Normalizamos formato de campos de las columnas añadiendo la configuración final para todas las tablas

utmb19.drop(['pto_cat'],axis='columns',inplace=True) #damos de baja columnas

#Generamos las columnas restanetes

utmb19['carrera']=generador.carrera(len(utmb19),'utmb')
utmb19['anio']=generador.anio(len(utmb19),'2019')

utmb19=utmb19.reindex(columns=['posicion','tiempo','dif','nombre','club','pais','sex','cat','carrera','anio']) #Reorganizamos

# %%
utmb19.to_csv('../data/mod_csv/utmb2019mod.csv', index=False, index_label=False) 
utmb19.to_excel('../data/xlsx/utmb2019mod.xlsx', index=False, index_label=False) #cargamos csv

# %% [markdown]
# #UTMB21

# %%
utmb21=pd.read_csv('../data/utmb2021.csv')

# %%
utmb21.drop(0,axis=0,inplace=True)  #Eliminamos primera columna de nulos

columns=['posicion','nombre','cat','pto_cat', 'tiempo','dif','pais']
utmb21.set_axis(columns,axis='columns',inplace=True)  #Modificamos el nombre de las columnas

# %%
##Modificamos en un solo bucle la columna de cat separando el dato del texto y normalizando el contenido. Además quitamos el float de la columna pto_cat

utmb21['sex']=utmb21.cat
for i in range(1,len(utmb21)+1):
    utmb21.sex[i]=str(utmb21.cat[i])[-1]        #rellenamos la columna sexo con el dato
    utmb21.cat[i]=str(utmb21.cat[i])[:2]        #dejamos solo el dato de categoria en cat
    utmb21.pto_cat[i]=str(utmb21.pto_cat[i])[0] #limpiamos pto_cat
    
    #Normalizamos los datos de sexo
    if utmb21.sex[i]=='n':
        utmb21.sex[i]='N/D'
    elif utmb21.sex[i]=='H':
        utmb21.sex[i]='M'
    elif utmb21.sex[i]=='n':
        utmb21.sex[i]='N/D'
    
    #Normalizamos datos en la columna cat
    if utmb21.cat[i]=='SE' or utmb21.cat[i]=='ES':
       utmb21.cat[i]='SENIOR'
    elif utmb21.cat[i]=='V1':
        utmb21.cat[i]='VET-A'
    elif utmb21.cat[i]=='V2':
        utmb21.cat[i]='VET-B'
    elif utmb21.cat[i]=='V3' or utmb21.cat[i]=='V4': 
        utmb21.cat[i]='VET-C'
    elif utmb21.cat[i]=='na':
        utmb21.cat[i]='N/D'
utmb21.cat.fillna(value='N/D')
        
utmb21.cat.unique()
# Out:
# array(['SENIOR', 'VET-A', 'VET-B', 'VET-C'], dtype=object)

# %%
##Modificamos la columna de nombre donde esta el dato del dorsal, nombre y club y lo separamos en diferentes listas que luego metemos en las columnas correspondientes

equipos=[]
nombres=[]
for i in utmb21.nombre:
    try:
        div=str(i).split('\n')
        equipos.append(div[1].split('/')[0].upper())
    except:
        equipos.append('NONE')
    
    
    #Normalizamos el nombre con la estructura Nombre APELLIDO
    div_nom=div[0].upper().split('-')
    limpiar_nombre=div_nom[1].split()
    temp=[]
    temp.append(limpiar_nombre)
    temp[0]=limpiar_nombre[-1].lower().capitalize()
    temp[1:]=limpiar_nombre[:-1]
    nombres.append(" ".join(temp))
    
utmb21.nombre=nombres
utmb21['club']=equipos

# %%
utmb21=utmb21.reindex(columns=['posicion','tiempo','dif','nombre','club','pais','sex','cat','pto_cat'])  #Recolocamos las columnas

utmb21.reset_index(drop=True,inplace=True)  #Reseteamos el index

# %%
utmb21.head()
# Out:
#    posicion    tiempo       dif             nombre               club  \
# 0         1  20:46:00  00:00:00   François D'HAENE              CMSAB
# 1         2  20:58:31  00:12:31             Dunand  TEAM COMPRESSPORT
# 2         3  21:12:44  00:26:44  Mathieu BLANCHARD            SALOMON
# 3         4  21:38:45  00:52:45   Ludovic POMMERET       HOKA ONE ONE
# 4         5  21:52:47  01:06:47   Germain GRANGIER                 ON
#
#       pais sex     cat pto_cat
# 0  Francia   M  SENIOR       1
# 1  Francia   M  SENIOR       2
# 2  Francia   M  SENIOR       3
# 3  Francia   M   VET-A       1
# 4  Francia   M  SENIOR       4

# %%
#Modificamos la columna de idiomas que no está totalmente correcta


utmb21.pais[utmb21.pais=='HK']='Hong Kong'

# %%
#Normalizamos formato de campos de las columnas añadiendo la configuración final para todas las tablas

utmb21.drop(['pto_cat'],axis='columns',inplace=True) #damos de baja columnas

#Generamos las columnas restanetes

utmb21['carrera']=generador.carrera(len(utmb21),'utmb')
utmb21['anio']=generador.anio(len(utmb21),'2021')

utmb21=utmb21.reindex(columns=['posicion','tiempo','dif','nombre','club','pais','sex','cat','carrera','anio']) #Reorganizamos

# %%
utmb21.to_csv('../data/mod_csv/utmb2021mod.csv', index=False, index_label=False)  
utmb21.to_excel('../data/xlsx/utmb2021mod.xlsx', index=False,index_label=False) #cargamos csv

# %% [markdown]
# #UTMB22

# %%
utmb22=pd.read_csv('../data/utmb2022.csv')

# %%
utmb22.head()
# Out:
#    index                                            0       1    2         3  \
# 0      0                                          NaN     NaN  NaN       NaN
# 1      1           1 - JORNET BURGADA Kilian\nNNORMAL  35-39M  1.0  19:49:30
# 2      2              41 - BLANCHARD Mathieu\nSALOMON  35-39M  2.0  19:54:50
# 3      3  11 - EVANS Thomas\nADIDAS TERREX / RED BULL  20-34M  1.0  20:34:36
# 4      4                       3 - WALMSLEY Jim\nHOKA  20-34M  2.0  21:12:12
#
#           4               5
# 0       NaN             NaN
# 1  00:00:00          España
# 2  00:05:20         Francia
# 3  00:45:06     Reino Unido
# 4  01:22:42  Estados Unidos

# %%
utmb22.drop(0,axis=0,inplace=True)  #Eliminamos primera columna de nulos

columns=['posicion','nombre','cat','pto_cat', 'tiempo','dif','pais']
utmb22.set_axis(columns,axis='columns',inplace=True)  #Modificamos el nombre de las columnas

# %%
utmb22.cat.unique()
# Out:
# array(['35-39M', '20-34M', '40-44M', '20-34F', '45-49M', '55-59M',
#        '45-49F', '35-39F', '40-44F', '50-54M', '50-54F', '60-64M',
#        '65-69M', '55-59F', '70-74M', '60-64F'], dtype=object)

# %%
##Modificamos en un solo bucle la columna de cat separando el dato del texto y normalizando el contenido. Además quitamos el float de la columna pto_cat

utmb22['sex']=utmb22.cat
for i in range(1,len(utmb22)+1):
    utmb22.sex[i]=str(utmb22.cat[i])[-1]        #rellenamos la columna sexo con el dato
    utmb22.cat[i]=str(utmb22.cat[i])[:-1]        #dejamos solo el dato de categoria en cat
    utmb22.pto_cat[i]=str(utmb22.pto_cat[i])[0] #limpiamos pto_cat
    
    #Normalizamos los datos de sexo
    if utmb22.sex[i]=='n':
        utmb22.sex[i]='N/D'
    elif utmb22.sex[i]=='H':
        utmb22.sex[i]='M'
    elif utmb22.sex[i]=='n':
        utmb22.sex[i]='N/D'
    
    #Normalizamos datos en la columna cat
    if utmb22.cat[i]=='20-34' or utmb22.cat[i]=='35-39':
       utmb22.cat[i]='SENIOR'
    elif utmb22.cat[i]=='40-44' or utmb22.cat[i]=='45-49':
        utmb22.cat[i]='VET-A'
    elif utmb22.cat[i]=='50-54' or utmb22.cat[i]=='55-59':
        utmb22.cat[i]='VET-B'
    elif utmb22.cat[i]=='60-64' or utmb22.cat[i]=='65-69' or utmb22.cat[i]=='70-74': 
        utmb22.cat[i]='VET-C'
    

        
utmb22.cat.unique()
# Out:
# array(['SENIOR', 'VET-A', 'VET-B', 'VET-C'], dtype=object)

# %%
##Modificamos la columna de nombre donde esta el dato del dorsal, nombre y club y lo separamos en diferentes listas que luego metemos en las columnas correspondientes

equipos=[]
nombres=[]
for i in utmb22.nombre:
    try:
        div=str(i).split('\n')
        div_equip=div[1].split('/')
        equipos.append(div[1].split('/')[0].upper())
        
    except:
        equipos.append('NONE')
    
    
    #Normalizamos el nombre con la estructura Nombre APELLIDO
    div_nom=div[0].upper().split('-')
    limpiar_nombre=div_nom[1].split()
    temp=[]
    temp.append(limpiar_nombre)
    temp[0]=limpiar_nombre[-1].lower().capitalize()
    temp[1:]=limpiar_nombre[:-1]
    nombres.append(" ".join(temp))
    
    
utmb22.nombre=nombres
utmb22['club']=equipos

# %%
utmb22=utmb22.reindex(columns=['posicion','tiempo','dif','nombre','club','pais','sex','cat','pto_cat'])  #Recolocamos las columnas

utmb22.reset_index(drop=True,inplace=True)  #Reseteamos el index

# %%
utmb22.head()
# Out:
#    posicion    tiempo       dif                 nombre            club  \
# 0         1  19:49:30  00:00:00  Kilian JORNET BURGADA         NNORMAL
# 1         2  19:54:50  00:05:20      Mathieu BLANCHARD         SALOMON
# 2         3  20:34:36  00:45:06           Thomas EVANS  ADIDAS TERREX
# 3         4  21:12:12  01:22:42           Jim WALMSLEY            HOKA
# 4         5  21:27:50  01:38:20            Zach MILLER  THE NORTH FACE
#
#              pais sex     cat pto_cat
# 0          España   M  SENIOR       1
# 1         Francia   M  SENIOR       2
# 2     Reino Unido   M  SENIOR       1
# 3  Estados Unidos   M  SENIOR       2
# 4  Estados Unidos   M  SENIOR       3

# %%
#Modificamos la columna de idiomas que no está totalmente correcta

utmb22.pais[utmb22.pais=='TW']='Taiwan'
utmb22.pais[utmb22.pais=='HK']='Hong Kong'
utmb22.pais[utmb22.pais=='XK']='Kosovo'

# %%
#Normalizamos formato de campos de las columnas añadiendo la configuración final para todas las tablas

utmb22.drop(['pto_cat'],axis='columns',inplace=True) #damos de baja columnas

#Generamos las columnas restanetes

utmb22['carrera']=generador.carrera(len(utmb22),'utmb')
utmb22['anio']=generador.anio(len(utmb22),'2022')

utmb22=utmb22.reindex(columns=['posicion','tiempo','dif','nombre','club','pais','sex','cat','carrera','anio']) #Reorganizamos

# %%
utmb22.to_csv('../data/mod_csv//utmb2022mod.csv', index=False, index_label=False) 
utmb22.to_csv('../data/xlsx/utmb2022mod.xlsx', index=False, index_label=False)  #cargamos csv

# %%
utmb=pd.concat([utmb17,utmb18,utmb19,utmb21,utmb22])

# %%
utmb.club.value_counts()
# Out:
# NONE                                                                             3643
# COLUMBIA                                                                           25
# UA SOCIETE GENERALE                                                                21
# CMBM                                                                               19
# SALOMON                                                                            18
# S                                                                                  18
# THE NORTH FACE                                                                     14
# INDEPENDIENTE                                                                      13
# HOKA ONE ONE                                                                       13
# TEAM VIBRAM                                                                        13
# KIKOUROU                                                                           11
# CREWSTACH                                                                          11
# NRG                                                                                 9
# A TO TRAPO                                                                          8
# AIX ATHLE PROVENCE                                                                  8
# SMAC                                                                                8
# FAITHWALKERS                                                                        7
# HOKA                                                                                7
# SAMBA TRAIL RUNNING CLUB                                                            7
# TEAM 100 MILE                                                                       7
# TEAM IRON RACE                                                                      7
# CAP ENDURANCE                                                                       7
# AVOC                                                                                7
# AIRBUS RUNNING                                                                      6
# COLUMBIA MONTRAIL                                                                   6
# CLAPHAM CHASERS                                                                     6
# COMPRESSPORT                                                                        6
# FLYING BOOSTY                                                                       6
# SRD 315 SJEVEROZAPAD                                                                6
# RUNNING PANDA                                                                       6
# PAREDES AVENTURA                                                                    6
# SERPENTINE                                                                          6
# TEAM100MILE                                                                         6
# ASC BNP PARIBAS PARIS                                                               5
# ALPINO BENALMADENA IRONTRIATH                                                       5
# ASPTT ANNECY                                                                        5
# AS CHU NANTES                                                                       5
# TEAM TRAIL CHOLET                                                                   5
# CORREMON TRAIL                                                                      5
# MOGU DUGO                                                                           5
# ACPA                                                                                5
# QUAN^2                                                                              5
# SPAC                                                                                5
# COTENTRAIL                                                                          5
# FA RUNNERS                                                                          5
# ARISTA                                                                              5
# AIIIIIIIADELANTE TEAM                                                               5
# SAONE MONT D'OR NATURE                                                              5
# THE NORTH FACE ADVENTURE TEAM                                                       5
# RAIDLIGHT                                                                           5
# SUMMANO COBRAS                                                                      5
# PENA GUARA                                                                          5
# TRAIL & PANDELYGTESJOV                                                              5
# BAZTANDARRAK                                                                        5
# SAMOENS TRAIL TEAM                                                                  5
# PORTET ATHLETIC CLUB                                                                5
# SALTA BARTAS                                                                        4
# VERONA TRAIL RUNNERS                                                                4
# CLUBE DE MONTANHA DO FUNCHAL                                                        4
# MONSANTO RUNNING TEAM                                                               4
# ORANGE POLSKA                                                                       4
# SCOTT RUNNING                                                                       4
# SISPORT                                                                             4
# MBDA SPORT ATHLETISME                                                               4
# COURIR A COMINES                                                                    4
# SUTRAIL                                                                             4
# EFSRA                                                                               4
# CERN RUNNING CLUB                                                                   4
# ROAD RUNNERS CLUB MILANO                                                            4
# UCD ROOM 22 RUNNERS                                                                 4
# MYNYDDWYR DE CYMRU                                                                  4
# DOA                                                                                 4
# GRUPPO SPORTIVO MERCURYUS                                                           4
# KESWICK AC                                                                          4
# UCCV                                                                                4
# THE PEAK HUNTER                                                                     4
# RUNNING MADHOUSE                                                                    4
# LES CHEVALIERS DU VENT                                                              4
# SALEVE TRAIL                                                                        4
# SPHENISCUS                                                                          4
# LA SPORTIVA                                                                         4
# ESTY                                                                                4
# JOGGERS DU COUESNON                                                                 4
# SA MILANA - ALARO                                                                   4
# TEAM NORDIC TRAIL                                                                   4
# LONESOME RUNNERS                                                                    4
# TEAM TRAIL JURA                                                                     4
# SG HERICOURT                                                                        4
# ILKLEY HARRIERS                                                                     3
# COLMAR TRAIL AVENTURES                                                              3
# SALAMANDRECOS                                                                       3
# LES VIEUX GARCONS                                                                   3
# MADEIRA TRAIL TEAM                                                                  3
# CAHORS TRAIL                                                                        3
# GAP HAUTES ALPES ATHLETISME                                                         3
# AAA DU LYONNAIS                                                                     3
# DR. MERINO                                                                          3
# CLUB 26 ALLAN                                                                       3
# COURIR LE MONDE                                                                     3
# KALENJI TEAM                                                                        3
# CIMAVILLA RUNNING TEAM                                                              3
# ATLETICA MANARA                                                                     3
# IMPULSION TRAIL ANGERS                                                              3
# OCS PROAVENTURAS                                                                    3
# ERRANCE REIMS EUROPE CLUB                                                           3
# TEAM RAIDLIGHT 44                                                                   3
# LONS ATHLE 39                                                                       3
# MARTIGNAT                                                                           3
# LES ROUILLES TEAM TRAIL                                                             3
# INOV-8                                                                              3
# ADIDAS TERREX                                                                       3
# ROLEX SPORT                                                                         3
# PLAYLIFE PONZANO                                                                    3
# COLUMBIA THAILAND                                                                   3
# AMCF-ARRABIDA TRAIL TEAM                                                            3
# HERCOG RUNNING TEAM                                                                 3
# 100% TRAIL ANGERS                                                                   3
# JULBO                                                                               3
# OUEST TRAIL REUNION                                                                 3
# INDIVIDUAL                                                                          3
# A LES NOU                                                                           3
# TEAM MARGUAREIS                                                                     3
# CAP GARONNE                                                                         3
# LIBERO                                                                              3
# MADTEAM                                                                             3
# ENDURANCE SCHOOL                                                                    3
# TAILLEFER TRAIL TEAM                                                                3
# LES ZINZINS DES COTEAUX 31                                                          3
# COTEN'TRAIL                                                                         3
# COMPRESSPORT INTERNATIONAL                                                          3
# TRAILBLAZERS                                                                        3
# TEAM TRAIL PARIS                                                                    3
# FALCOTRAIL CEHEGIN                                                                  3
# ARCH                                                                                3
# JCPLP                                                                               3
# TEAM LA SPORTIVA                                                                    3
# ISB NU TEAM                                                                         3
# TRBB                                                                                3
# LEOPODISTICA                                                                        3
# YANEZ RUNNERS                                                                       3
# TEAM TRAIL TOURAINE                                                                 3
# TRAILWAY                                                                            3
# CA DENTS DU MIDI                                                                    3
# AS MAGENTA                                                                          3
# ESKILSTUNA TRAILKLUBB                                                               3
# BGSA                                                                                3
# OSK115 TRAIL                                                                        3
# EASC                                                                                2
# JARAPALOS TRAIL                                                                     2
# RRRC                                                                                2
# TCHIMBE RAID                                                                        2
# KRUNNERS                                                                            2
# CLUB ATLETISME ARTA                                                                 2
# QNB FINANSBANK                                                                      2
# VERTICAL SPORT ROMANIA                                                              2
# CLUB26ALLAN                                                                         2
# TEAM RAIDLIGHT                                                                      2
# ASPHALTE 94                                                                         2
# 庄内ゆるラン                                                                              2
# ENT'RAID 49                                                                         2
# CLUBE ZUPPER                                                                        2
# RAC                                                                                 2
# ASD VIGONECHECORRE                                                                  2
# ATHLEFORM42                                                                         2
# TRIA EQUIPE ELZ                                                                     2
# ROCKLIZARDS                                                                         2
# COURMAYEUR TRAILERS                                                                 2
# AMC AUBAGNE                                                                         2
# TEAM TRAIL 17                                                                       2
# WUJEK BIEGA                                                                         2
# ASPTT VERDUN                                                                        2
# CLUB TRAIL ALBACETE                                                                 2
# TEAM VEGAN.AT                                                                       2
# JERRY GARCIA TRAIL                                                                  2
# TRAIL SERRA VERNISSA                                                                2
# OTC COMO                                                                            2
# TRAIL VERNET AVENTURE                                                               2
# C.A. DIANIUM TURURAC                                                                2
# DIVE INTO THE MOUNTAINS                                                             2
# GLOBETRAILERS                                                                       2
# MATES                                                                               2
# AIA VITALITY                                                                        2
# PIERREVAL                                                                           2
# CIUCAS X3                                                                           2
# BRUNO BRUNOD RACING TEAM                                                            2
# STEFANIKTRAIL.SK                                                                    2
# KANINOS                                                                             2
# ORANGE PRESSEE                                                                      2
# COLLA EL PAROTET                                                                    2
# PURETRAIL RUNNING                                                                   2
# TTDA                                                                                2
# USC NOUVION SUR MEUSE                                                               2
# LA VARA TRAIL                                                                       2
# TEAM FENIX                                                                          2
# LES TRAILEURS DE LA POINTE                                                          2
# TEAM 100 MILES                                                                      2
# CAES D´AVENIDA                                                                      2
# CA BRIOUDE                                                                          2
# CORSICA RUN XTREM                                                                   2
# SO HOUILLES                                                                         2
# TRIWAWA                                                                             2
# GET FIT                                                                             2
# TRAIL MONSTER RUNNING                                                               2
# CLCS FIRMINY                                                                        2
# YTRAC CLUB NATURE                                                                   2
# GETFIT                                                                              2
# WAA TEAM                                                                            2
# VENITI CU NOI ARAD                                                                  2
# VHTRC                                                                               2
# TEAM OLYMPIQUE SUPER BOCK                                                           2
# BICHOS RUNNERS                                                                      2
# UEC TORTOSA                                                                         2
# CAP BOLLENE                                                                         2
# P-WEG-TEAM                                                                          2
# MATAMON TRAIL                                                                       2
# AMIGOS DO PEDAL TRAIL DE LAGARES                                                    2
# BUFF PRO TEAM                                                                       2
# GLI ORSI A.S.D.                                                                     2
# CORCY ENDURANCE                                                                     2
# CERREDO 643                                                                         2
# MARATHON MISILMERI                                                                  2
# O.C.S                                                                               2
# CLUB CICLISTA GUERRER DE MOIXENT                                                    2
# CLUBE ATLETISMO FAFE                                                                2
# CROSSCALL                                                                           2
# STAY INSANE                                                                         2
# CCA ROUFFACH                                                                        2
# INVICTUS                                                                            2
# TRA                                                                                 1
# AURRERA M.T. - ONDARROA                                                             1
# BLUE O                                                                              1
# BEDOIN CYCLO SPORT                                                                  1
# SC ARLES                                                                            1
# ATLETICA VAL BREMBANA                                                               1
# SUNT IN FORMA                                                                       1
# TEAM IRONRACE                                                                       1
# AC ST REMY DE PROVENCE                                                              1
# ENT'RAID                                                                            1
# DES SPORTS DE MEGEVE                                                                1
# ROLLS-ROYCE HARRIERS                                                                1
# GENARPS IF                                                                          1
# KALENJI ULTRA TRAIL TEAM                                                            1
# 大连海事大学@西安电子科技大学                                                                     1
# ROSSENDALE HARRIERS & ATHLETIC CLUB                                                 1
# BLUE TRIBE                                                                          1
# KRATOS TEAM                                                                         1
# ATHLETISME SAINT-PANTALEON                                                          1
# WTL LAXOU                                                                           1
# WTL                                                                                 1
# UTTG CLUB                                                                           1
# THALES                                                                              1
# 226 LONG DISTANCE                                                                   1
# BOBCATS                                                                             1
# BASECAMP                                                                            1
# ESSPO                                                                               1
# SENIOREN LAUFTREFF                                                                  1
# AMATORI ATLETICA CHIRIGNAGO                                                         1
# TRIATHLON VC ALLSCHWIL                                                              1
# UNIO EXCURSIONISTA DE CATALUNYA-SANTS                                               1
# KLUB WYSOKOGORSKI W JASTRZĘBIU-ZDROJU                                               1
# C.D.TRAIL RUNNING MALAGA                                                            1
# ATLETICA PARATICO                                                                   1
# TEAM LAHNSTEINER BRAUEREI                                                           1
# ASD FREE RUNNERS                                                                    1
# DURANGO RUNNING CLUB                                                                1
# CENTRE EXC. LLORENCA                                                                1
# ATLETICA CASONE, NOCETO                                                             1
# PLM CONFLANS                                                                        1
# BEER RUNNERS BARCELONA                                                              1
# ADVENTURE KAJAK                                                                     1
# CEIBS RUNNING CLUB                                                                  1
# TROTONES CLUB                                                                       1
# C.A. ALCOY                                                                          1
# AIIIIIDELANTE TEAM                                                                  1
# CB SPORT PODISTICA CARAMAGNA                                                        1
# ORJEN OUTDOOR                                                                       1
# SRD315SJEVEROZAPA                                                                   1
# NTP-SASEBO                                                                          1
# Name: club, dtype: int64

# %%
marcas=generador.marca(utmb.club)

# %%
utmb['marcas']=marcas

utmb=utmb.reindex(columns=['posicion','tiempo','dif','nombre','club','marcas','pais','sex','cat','carrera','anio']) #Reorganizamos

# %%
utmb.to_csv('../data/mod_csv/utmb.csv',index=False, index_label=False)
utmb.to_excel('../data/xlsx/utmb.xlsx',index=False, index_label=False)

# %%
utmb.columns
# Out:
# Index(['posicion', 'tiempo', 'dif', 'nombre', 'club', 'marcas', 'pais', 'sex',
#        'cat', 'carrera', 'anio'],
#       dtype='object')

# %%
utmb_mujeres=utmb[utmb.sex=='F']

utmb_hombres=utmb[utmb.sex=='H']

utmb_mujeres.to_excel('../data/xlsx/utmb_mujeres.xlsx')
utmb_hombres.to_excel('../data/xlsx/utmb_hombres.xlsx')

# %%
utmb_hombres=utmb[utmb.sex=='M']
utmb_hombres.to_excel('../data/xlsx/utmb_hombres.xlsx')
