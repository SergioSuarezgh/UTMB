# %%
from selenium import webdriver
from selenium import webdriver # driver de selenium
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.common.by import By   # para buscar segun tag, id, class, etc...
import time   # pa%pip install requestsra manejar tiempo
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.support.ui import WebDriverWait   # es para esperar
from selenium.webdriver.support import expected_conditions as EC  # condiciones esperadas...
from selenium.webdriver import ActionChains as AC   # acciones encadenadas, rollo doble click
from selenium.webdriver.common.action_chains import ActionChains
from selenium.webdriver.common.keys import Keys  # manejar teclas
import pandas as pd


import asyncio


from joblib import Parallel, delayed

from tqdm.notebook import tqdm


import warnings
warnings.filterwarnings('ignore')


pd.set_option('display.max_columns',None)
pd.set_option('display.max_rows',None)

# %%
PATH=ChromeDriverManager().install()

# %% [markdown]
# ###Descargar con selenium info de la pagina de la carrera del utmb

# %%
##Accedemos a una tabla de resultados y la descargamos


driver=webdriver.Chrome(PATH) 
utmb_url='https://utmbmontblanc.com/es/page/107/107.html'
driver.get(utmb_url) 
tabla=driver.find_element(By.XPATH, '//*[@id="ct107"]/div[2]/div[2]/div[2]/span[2]/input').click()

time.sleep(2)

element= driver.find_element(By.TAG_NAME,'table')

filas=element.find_elements(By.TAG_NAME,'tr')

data=[]

for f in filas:
    
    elemen=f.find_elements(By.TAG_NAME, 'td')
    
    tmp=[]
    
    for e in elemen:
        
        tmp.append(e.text)
        
    data.append(tmp)

    
df=pd.DataFrame(data)
#time.sleep(2)
#for fila in filas:
#    print(fila.text)


time.sleep(2)
#driver.get(utmb_url)

# %%
##Ejecutamos la función asincrona

def asincrono(funcion):
    
    def eventos(*args, **kwargs):
        return asyncio.get_event_loop().run_in_executor(None, funcion, *args, **kwargs)
    
    return eventos

# %%
##Creamos una función para intentar descargarnos todos los resultados de varios años a la vez

def utmb(i):  #i es el número de la tabla que n os queremos descargar
    PATH=ChromeDriverManager().install()
    driver=webdriver.Chrome(PATH) 
    utmb_url='https://utmbmontblanc.com/es/page/107/107.html'
    driver.get(utmb_url) 
    
    try:
       
        tabla=driver.find_element(By.XPATH, f'//*[@id="ct107"]/div[2]/div[{i}]/div[2]/span[2]/input').click()

        time.sleep(2)

        element= driver.find_element(By.TAG_NAME,'table')

        filas=element.find_elements(By.TAG_NAME,'tr')

        data=[]

        for f in filas:
                
            elemen=f.find_elements(By.TAG_NAME, 'td')
                
            tmp=[]
                
            for e in elemen:
                    
                tmp.append(e.text)
                    
            data.append(tmp)
        driver.quit()
        return pd.DataFrame(data)
    except:
        print(f'error en punto{i}')
    

        
##Intentamos en varias ocasiones descagarla de forma asincrona pero da errorr asi que la descargamos de una en una

# %%
#lst_df=Parallel(n_jobs=4, verbose=True)(delayed(utmb)(num) for num in range(2,19))

# %%
'''utmb2022=utmb(2)
utmb2021=utmb(3)
utmb2019=utmb(4)
utmb2018=utmb(5)
utmb2017=utmb(6)
utmb2016=utmb(7)
utmb2015=utmb(8)
utmb2014=utmb(9)
utmb2013=utmb(10)
utmb2012=utmb(11)
utmb2011=utmb(12)
utmb2009=utmb(14)
utmb2008=utmb(15)
utmb2007=utmb(16)
utmb2006=utmb(17)
utmb2005=utmb(18)
utmb2004=utmb(19)'''
# Out:
# Future exception was never retrieved
# future: <Future finished exception=WebDriverException()>
# Traceback (most recent call last):
#   File "c:\Users\sersu\anaconda3\lib\concurrent\futures\thread.py", line 58, in run
#     result = self.fn(*self.args, **self.kwargs)
#   File "C:\Users\sersu\AppData\Local\Temp\ipykernel_32012\300363245.py", line 7, in utmb
#     driver.get(utmb_url)
#   File "c:\Users\sersu\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py", line 455, in get
#     self.execute(Command.GET, {"url": url})
#   File "c:\Users\sersu\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py", line 444, in execute
#     self.error_handler.check_response(response)
#   File "c:\Users\sersu\anaconda3\lib\site-packages\selenium\webdriver\remote\errorhandler.py", line 249, in check_response
#     raise exception_class(message, screen, stacktrace)
# selenium.common.exceptions.WebDriverException: Message: target frame detached
# ...

# %%
'''utmb2021=utmb(3)
utmb2019=utmb(4)
utmb2013=utmb(10)
'''

# %%
columns=['clasificación','nombre_club', 'cat','clasificacion', 'tiempo', 'diferencia', 'nacionalidad']

# %%
##Reseteamos los indices de todas

utmb2022.reset_index(level=None, drop=False, inplace=True, col_level=0, col_fill='')
utmb2021.reset_index(level=None, drop=False, inplace=True, col_level=0, col_fill='')
utmb2019.reset_index(level=None, drop=False, inplace=True, col_level=0, col_fill='')
utmb2018.reset_index(level=None, drop=False, inplace=True, col_level=0, col_fill='')
utmb2017.reset_index(level=None, drop=False, inplace=True, col_level=0, col_fill='')
utmb2016.reset_index(level=None, drop=False, inplace=True, col_level=0, col_fill='')
utmb2015.reset_index(level=None, drop=False, inplace=True, col_level=0, col_fill='')
utmb2014.reset_index(level=None, drop=False, inplace=True, col_level=0, col_fill='')
utmb2013.reset_index(level=None, drop=False, inplace=True, col_level=0, col_fill='')
utmb2012.reset_index(level=None, drop=False, inplace=True, col_level=0, col_fill='')
utmb2011.reset_index(level=None, drop=False, inplace=True, col_level=0, col_fill='')
utmb2009.reset_index(level=None, drop=False, inplace=True, col_level=0, col_fill='')
utmb2008.reset_index(level=None, drop=False, inplace=True, col_level=0, col_fill='')
utmb2007.reset_index(level=None, drop=False, inplace=True, col_level=0, col_fill='')
utmb2006.reset_index(level=None, drop=False, inplace=True, col_level=0, col_fill='')
utmb2005.reset_index(level=None, drop=False, inplace=True, col_level=0, col_fill='')
utmb2004.reset_index(level=None, drop=False, inplace=True, col_level=0, col_fill='')

# %%
##Las subimos a csv


utmb2022.to_csv('data/utmb2022.csv',index=False)
utmb2021.to_csv('data/utmb2021.csv',index=False)
utmb2019.to_csv('data/utmb2019.csv',index=False)
utmb2018.to_csv('data/utmb2018.csv',index=False)
utmb2017.to_csv('data/utmb2017.csv',index=False)
utmb2016.to_csv('data/utmb2016.csv',index=False)
utmb2015.to_csv('data/utmb2015.csv',index=False)
utmb2014.to_csv('data/utmb2014.csv',index=False)
utmb2013.to_csv('data/utmb2013.csv',index=False)
utmb2012.to_csv('data/utmb2012.csv',index=False)
utmb2011.to_csv('data/utmb2011.csv',index=False)
utmb2009.to_csv('data/utmb2009.csv',index=False)
utmb2008.to_csv('data/utmb2008.csv',index=False)
utmb2007.to_csv('data/utmb2007.csv',index=False)
utmb2006.to_csv('data/utmb2006.csv',index=False)
utmb2005.to_csv('data/utmb2005.csv',index=False)
utmb2004.to_csv('data/utmb2004.csv',index=False)

# %%
##Lo ejecutamos en paralelo y esta vez si funciona

num_pag=[1,2,3,4]

lst_df=Parallel(n_jobs=6, verbose=True)(delayed(meridiano)(num) for num in tqdm(num_pag))
# Out:
#   0%|          | 0/4 [00:00<?, ?it/s]
# [Parallel(n_jobs=6)]: Using backend LokyBackend with 6 concurrent workers.
# [Parallel(n_jobs=6)]: Done   4 out of   4 | elapsed:  2.0min finished

# %%
utmb2022.to_excel('data/utmb2022.csv',index=False)
utmb2021.to_excel('data/utmb2021.csv',index=False)
utmb2019.to_excel('data/utmb2019.csv',index=False)
utmb2018.to_excel('data/utmb2018.csv',index=False)
utmb2017.to_excel('data/utmb2017.csv',index=False)
utmb2016.to_excel('data/utmb2016.csv',index=False)
utmb2015.to_excel('data/utmb2015.csv',index=False)
utmb2014.to_excel('data/utmb2014.csv',index=False)
utmb2013.to_excel('data/utmb2013.csv',index=False)
utmb2012.to_excel('data/utmb2012.csv',index=False)
utmb2011.to_excel('data/utmb2011.csv',index=False)
utmb2009.to_excel('data/utmb2009.csv',index=False)
utmb2008.to_excel('data/utmb2008.csv',index=False)
utmb2007.to_excel('data/utmb2007.csv',index=False)
utmb2006.to_excel('data/utmb2006.csv',index=False)
utmb2005.to_excel('data/utmb2005.csv',index=False)
utmb2004.to_excel('data/utmb2004.csv',index=False)
